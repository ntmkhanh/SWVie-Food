# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/NCKH
# Out:
# /content/drive/MyDrive/NCKH

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
pwd
# Out:
# '/content/drive/MyDrive/NCKH/yolov5'

# %%
cd NCKH
# Out:
# [Errno 2] No such file or directory: 'NCKH'
# /content/drive/MyDrive/NCKH

# %%
# !pip install -qr requirements.txt

# %%
cd yolov5
# Out:
# /content/drive/MyDrive/NCKH/yolov5

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="b59vcaTEBUv4mucgcgEe")
project = rf.workspace("my-khanh-nguyen").project("nckh-cm81q")
dataset = project.version(12).download("yolov5")

# %%
pwd
# Out:
# '/content/drive/MyDrive/NCKH'

# %%
# !python '/content/drive/MyDrive/NCKH/yolov5/train.py' --img 640 --batch 16 --epochs 50 --data '/content/drive/MyDrive/NCKH/yolov5/NCKH-12/data.yaml' --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/NCKH/yolov5/NCKH-12/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 126 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-253-g75bbaa8 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !display.Image(filename='/content/drive/MyDrive/NCKH/yolov5/runs/detect/exp/caloc10.jpg', width=600)

# %%
# !pip install -q tflite-model-maker

# %%
# !python '/content/drive/MyDrive/NCKH/yolov5/detect.py' --weights '/content/drive/MyDrive/NCKH/yolov5/runs/train/exp5/weights/best.pt' --img 640 --conf 0.3 --source '/content/drive/MyDrive/NCKH/a'

# %%
# !python '/content/drive/MyDrive/NCKH/yolov5/export.py' --weights '/content/drive/MyDrive/NCKH/yolov5/runs/train/exp5/weights/best.pt' --include tflite --img 640

# %%
cd ..
# Out:
# /content/drive/MyDrive/NCKH/yolov5

# %%
# !python '/content/drive/MyDrive/NCKH/yolov5/export.py' --weights yolov5x.pt --include tflite

# %%
# !pip install -q tflite-model-maker

# %%
from tflite_model_maker import image_classifier
from tflite_model_maker.image_classifier import DataLoader

import tensorflow as tf
assert tf.__version__.startswith('2')

import matplotlib.pyplot as plt
import numpy as np

# %%
pwd
# Out:
# '/content/drive/MyDrive/NCKH/yolov5'

# %%
cd runs
# Out:
# /content/drive/MyDrive/NCKH/yolov5/runs

# %%
# !python '/content/drive/MyDrive/NCKH/yolov5/export.py' --weights '/content/drive/MyDrive/NCKH/yolov5/runs/train/exp5/weights/best.pt' --img 640 --include saved_model

# %%
import tensorflow as tf # 2.4.1
from tensorflow.keras.models import load_model

model = load_model('/content/drive/MyDrive/NCKH/yolov5/runs/train/exp2/weights/best.pt') # .model or .h5 file

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open("activity-lite.tflite", "wb") as f:
    f.write(tflite_model)

# %%
# !python '/content/drive/MyDrive/NCKH/yolov5/export.py' --weights '/content/drive/MyDrive/NCKH/yolov5/runs/train/exp2/weights/best.pt' --include tflite --int8 --img 640 --data '/content/drive/MyDrive/NCKH/yolov5/NCKH-2/data.yaml'

# %%
# !pip install tflite-support

# %%
# !python '/content/drive/MyDrive/NCKH/yolov5/export.py' --weights '/content/drive/MyDrive/NCKH/yolov5/runs/train/exp2/weights/best.pt' --include tflite

# %%
# !python '/content/drive/MyDrive/NCKH/yolov5/export.py' --weights '/content/drive/MyDrive/NCKH/yolov5/runs/train/exp2/weights/best.pt' --include tflite --half --device 0

# %%
cd yolov5
pip install -r requirements.txt

# %%
# !python path/to/export.py --weights yolov5s.pt --include torchscript onnx
